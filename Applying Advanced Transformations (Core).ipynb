# %%
## Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
## Importing the OS and JSON Modules
import os,json

# %%
Left = pd.read_csv('superhero_info - superhero_info.csv')
Left.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %%
Right= pd.read_csv('superhero_powers - superhero_powers.csv')
Right.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %% [markdown]
# Cleaning Left DF first

# %%
Left.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Hero|Publisher  463 non-null    object
#  1   Gender          463 non-null    object
#  2   Race            463 non-null    object
#  3   Alignment       463 non-null    object
#  4   Hair color      463 non-null    object
#  5   Eye color       463 non-null    object
#  6   Skin color      463 non-null    object
#  7   Measurements    463 non-null    object
# dtypes: object(8)
# memory usage: 29.1+ KB

# %% [markdown]
# Measurments needs to be split height and weight should be 2 columns and the values be the data in that column.

# %%
Left['Measurements'].head(2)
# Out:
# 0    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1     {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# Name: Measurements, dtype: object

# %%
to_replace = [',']
for char in to_replace:
    Left['Measurements'] = Left['Measurements'].str.replace(char,':',regex=False)

# %%
Left['Measurements'].str.split(':',expand=True)
# Out:
#              0            1          2             3
# 0    {'Height'   '203.0 cm'   'Weight'   '441.0 kg'}
# 1    {'Height'   '191.0 cm'   'Weight'    '65.0 kg'}
# 2    {'Height'   '185.0 cm'   'Weight'    '90.0 kg'}
# 3    {'Height'   '203.0 cm'   'Weight'   '441.0 kg'}
# 4    {'Height'   '193.0 cm'   'Weight'   '122.0 kg'}
# ..         ...          ...        ...           ...
# 458  {'Height'   '183.0 cm'   'Weight'    '83.0 kg'}
# 459  {'Height'   '165.0 cm'   'Weight'    '52.0 kg'}
# 460  {'Height'    '66.0 cm'   'Weight'    '17.0 kg'}
# 461  {'Height'   '170.0 cm'   'Weight'    '57.0 kg'}
# 462  {'Height'   '185.0 cm'   'Weight'    '81.0 kg'}
#
# [463 rows x 4 columns]

# %%
Left[['0','height (cm)','2','weight (kg)']] = Left['Measurements'].str.split(':',expand=True)
Left.head(2)
# Out:
#                  Hero|Publisher Gender           Race Alignment Hair color  \
# 0          A-Bomb|Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien|Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color                                  Measurements  \
# 0    yellow    Unknown  {'Height': '203.0 cm': 'Weight': '441.0 kg'}
# 1      blue       blue   {'Height': '191.0 cm': 'Weight': '65.0 kg'}
#
#            0  height (cm)          2   weight (kg)
# 0  {'Height'   '203.0 cm'   'Weight'   '441.0 kg'}
# 1  {'Height'   '191.0 cm'   'Weight'    '65.0 kg'}

# %%
Left = Left.drop(columns=['Measurements', '0', '2'])
Left.head(2)
# Out:
#                  Hero|Publisher Gender           Race Alignment Hair color  \
# 0          A-Bomb|Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien|Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color  height (cm)   weight (kg)
# 0    yellow    Unknown   '203.0 cm'   '441.0 kg'}
# 1      blue       blue   '191.0 cm'    '65.0 kg'}

# %%
to_replace = ["'", ' cm', ' kg', '}',' ']
for char in to_replace:
    Left['height (cm)'] = Left['height (cm)'].str.replace(char,'',regex=False)

# %%
to_replace = ["'", 'cm', 'kg', '}',' ']
for char in to_replace:
    Left['weight (kg)'] = Left['weight (kg)'].str.replace(char,'',regex=False)

# %%
Left.head(2)
# Out:
#                  Hero|Publisher Gender           Race Alignment Hair color  \
# 0          A-Bomb|Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien|Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color height (cm) weight (kg)
# 0    yellow    Unknown       203.0       441.0
# 1      blue       blue       191.0        65.0

# %%
Left.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Hero|Publisher  463 non-null    object
#  1   Gender          463 non-null    object
#  2   Race            463 non-null    object
#  3   Alignment       463 non-null    object
#  4   Hair color      463 non-null    object
#  5   Eye color       463 non-null    object
#  6   Skin color      463 non-null    object
#  7   height (cm)     463 non-null    object
#  8   weight (kg)     463 non-null    object
# dtypes: object(9)
# memory usage: 32.7+ KB

# %% [markdown]
# Addressing Hero Column by splitting column at pipe then will create a hero column then I will remove pipe and hero|Publisher column and 1 column

# %%
Left['Hero|Publisher'].str.split('|',expand=True)
# Out:
#                    0                  1
# 0             A-Bomb      Marvel Comics
# 1         Abe Sapien  Dark Horse Comics
# 2           Abin Sur          DC Comics
# 3        Abomination      Marvel Comics
# 4      Absorbing Man      Marvel Comics
# ..               ...                ...
# 458     Yellowjacket      Marvel Comics
# 459  Yellowjacket II      Marvel Comics
# 460             Yoda       George Lucas
# 461          Zatanna          DC Comics
# 462             Zoom          DC Comics
#
# [463 rows x 2 columns]

# %%
Left[['Hero','Publisher']] = Left['Hero|Publisher'].str.split('|',expand=True)
Left.head(2)
# Out:
#                  Hero|Publisher Gender           Race Alignment Hair color  \
# 0          A-Bomb|Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien|Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color height (cm) weight (kg)        Hero          Publisher
# 0    yellow    Unknown       203.0       441.0      A-Bomb      Marvel Comics
# 1      blue       blue       191.0        65.0  Abe Sapien  Dark Horse Comics

# %%
Left = Left.drop(columns=['Hero|Publisher'])
Left.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color height (cm)  \
# 0   Male          Human      good    No Hair    yellow    Unknown       203.0
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue       191.0
#
#   weight (kg)        Hero          Publisher
# 0       441.0      A-Bomb      Marvel Comics
# 1        65.0  Abe Sapien  Dark Horse Comics

# %%
unique_ids = sorted(Left['height (cm)'].unique())
unique_ids[:10]
# Out:
# ['122.0',
#  '137.0',
#  '142.0',
#  '15.2',
#  '155.0',
#  '157.0',
#  '160.0',
#  '163.0',
#  '165.0',
#  '168.0']

# %%
unique_ids = sorted(Left['weight (kg)'].unique())
unique_ids[:10]
# Out:
# ['101.0',
#  '104.0',
#  '105.0',
#  '106.0',
#  '108.0',
#  '110.0',
#  '113.0',
#  '115.0',
#  '116.0',
#  '117.0']

# %%
Left['height (cm)'] = Left['height (cm)'].astype(float)

# %%
Left['weight (kg) '] = Left['weight (kg)'].astype(float)

# %%
Left.dtypes
# Out:
# Gender           object
# Race             object
# Alignment        object
# Hair color       object
# Eye color        object
# Skin color       object
# height (cm)     float64
# weight (kg)      object
# Hero             object
# Publisher        object
# weight (kg)     float64
# dtype: object

# %%
Left.to_csv('superhero_info_clean.csv.gz', compression='gzip',index=False)

# %% [markdown]
# Starting right df we need to address the powers column will need to make column for each power by one-hot-encoding

# %%
## use .str.replace to replace all single quotes
Right['Powers'] = Right['Powers'].replace('\'', '\"')

# %%
power = Right.loc[2,'Powers']
print(type(power))
power
# Out:
# <class 'str'>
# 'Agility,Accelerated Healing,Cold Resistance,Durability,Underwater breathing,Marksmanship,Weapons Master,Longevity,Intelligence,Super Strength,Telepathy,Stamina,Immortality,Reflexes,Enhanced Sight,Sub-Mariner'

# %%
target = Right['Powers'].str.split(',')
target
# Out:
# 0        [Agility, Super Strength, Stamina, Super Speed]
# 1      [Accelerated Healing, Durability, Longevity, S...
# 2      [Agility, Accelerated Healing, Cold Resistance...
# 3                                   [Lantern Power Ring]
# 4      [Accelerated Healing, Intelligence, Super Stre...
#                              ...
# 662               [Flight, Energy Blasts, Size Changing]
# 663    [Cold Resistance, Durability, Longevity, Super...
# 664    [Agility, Stealth, Danger Sense, Marksmanship,...
# 665    [Cryokinesis, Telepathy, Magic, Fire Control, ...
# 666    [Super Speed, Intangibility, Time Travel, Time...
# Name: Powers, Length: 667, dtype: object

# %%
exploded = target.explode(ignore_index=False)
exploded
# Out:
# 0                  Agility
# 0           Super Strength
# 0                  Stamina
# 0              Super Speed
# 1      Accelerated Healing
#               ...
# 665        Weather Control
# 666            Super Speed
# 666          Intangibility
# 666            Time Travel
# 666      Time Manipulation
# Name: Powers, Length: 5874, dtype: object

# %%
cols_to_make = exploded.unique()
cols_to_make
# Out:
# array(['Agility', 'Super Strength', 'Stamina', 'Super Speed',
#        'Accelerated Healing', 'Durability', 'Longevity', 'Camouflage',
#        'Self-Sustenance', 'Cold Resistance', 'Underwater breathing',
#        'Marksmanship', 'Weapons Master', 'Intelligence', 'Telepathy',
#        'Immortality', 'Reflexes', 'Enhanced Sight', 'Sub-Mariner',
#        'Lantern Power Ring', 'Invulnerability', 'Animation',
#        'Super Breath', 'Dimensional Awareness', 'Flight', 'Size Changing',
#        'Teleportation', 'Magic', 'Dimensional Travel',
#        'Molecular Manipulation', 'Energy Manipulation', 'Power Cosmic',
#        'Energy Absorption', 'Elemental Transmogrification',
#        'Fire Resistance', 'Natural Armor', 'Heat Resistance',
#        'Matter Absorption', 'Regeneration', 'Stealth', 'Power Suit',
#        'Energy Blasts', 'Energy Beams', 'Heat Generation', 'Danger Sense',
#        'Phasing', 'Force Fields', 'Hypnokinesis', 'Invisibility',
#        'Enhanced Senses', 'Jump', 'Shapeshifting', 'Elasticity',
#        'Substance Secretion', 'Enhanced Hearing', 'Adaptation', 'Gliding',
#        'Natural Weapons', 'Wallcrawling', 'Vision - Thermal',
#        'Power Augmentation', 'Cryokinesis', 'Duplication',
#        'Weapon-based Powers', 'Fire Control', 'Enhanced Memory',
#        'Energy Constructs', 'Power Absorption', 'Time Travel',
#        'Enhanced Smell', 'Water Control', 'Vision - Telescopic',
#        'Magnetism', 'Vision - Microscopic', 'Vision - Night',
#        'Vision - Heat', 'Vision - X-Ray', 'Psionic Powers',
#        'Toxin and Disease Resistance', 'Animal Attributes',
#        'Animal Oriented Powers', 'Toxin and Disease Control', 'Empathy',
#        'Animal Control', 'Darkforce Manipulation', 'Time Manipulation',
#        'Reality Warping', 'Web Creation', 'Symbiote Costume',
#        'Telekinesis', 'Levitation', 'Biokinesis', 'Sonar',
#        'Enhanced Touch', 'Seismic Power', 'Energy Armor',
#        'Omnilingualism', 'Radiation Immunity', 'Density Control',
#        'Light Control', 'Illumination', 'Molecular Combustion',
#        'Astral Travel', 'Precognition', 'Intangibility', 'Illusions',
#        'Audio Control', 'Sonic Scream', 'Peak Human Condition',
#        'Vision - Infrared', 'Dexterity', 'Omnitrix', 'Omnipotent',
#        'Possession', 'Energy Resistance', 'Vision - Cryo', 'Mind Control',
#        'Mind Blast', 'Clairvoyance', 'Probability Manipulation',
#        'Death Touch', 'Electrokinesis', 'Gravity Control',
#        'Technopath/Cyberpath', 'Radar Sense', 'Astral Projection',
#        'Cloaking', 'Telepathy Resistance', 'Mind Control Resistance',
#        'Hyperkinesis', 'Spatial Awareness', 'Radiation Control',
#        'Radiation Absorption', 'Magic Resistance', 'Element Control',
#        'Plant Control', 'Terrakinesis', 'Power Sense', 'Wind Control',
#        'Qwardian Power Ring', 'Echolocation', 'Resurrection', 'The Force',
#        'Summoning', 'Banish', 'Molecular Dissipation',
#        'Electrical Transport', 'Speed Force', 'Grim Reaping',
#        'Portal Creation', 'Vitakinesis', 'Projection', 'Insanity',
#        'Photographic Reflexes', 'Anti-Gravity', 'Thirstokinesis',
#        'Power Nullifier', 'Weather Control', 'Omnipresent', 'Omniscient',
#        'Hair Manipulation', 'Nova Force', 'Odin Force', 'Phoenix Force',
#        'Intuitive aptitude', 'Melting', 'Changing Armor'], dtype=object)

# %%
for col in cols_to_make:
    Right[col] = Right['Powers'].str.contains(col)
Right.head()
# Out:
# c:\Users\staichn\Anaconda3\envs\dojo-env\lib\site-packages\ipykernel_launcher.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#     hero_names                                             Powers  Agility  \
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed     True
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...    False
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...     True
# 3     Abin Sur                                 Lantern Power Ring    False
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...    False
#
#    Super Strength  Stamina  Super Speed  Accelerated Healing  Durability  \
# 0            True     True         True                False       False
# 1            True     True        False                 True        True
# 2            True     True        False                 True        True
# 3           False    False        False                False       False
# 4            True     True         True                 True       False
#
#    Longevity  Camouflage  ...  Weather Control  Omnipresent  Omniscient  \
# 0      False       False  ...            False        False       False
# 1       True        True  ...            False        False       False
# 2       True       False  ...            False        False       False
# 3      False       False  ...            False        False       False
# 4      False       False  ...            False        False       False
#
#    Hair Manipulation  Nova Force  Odin Force  Phoenix Force  \
# 0              False       False       False          False
# 1              False       False       False          False
# 2              False       False       False          False
# 3              False       False       False          False
# 4              False       False       False          False
#
#    Intuitive aptitude  Melting  Changing Armor
# 0               False    False           False
# 1               False    False           False
# 2               False    False           False
# 3               False    False           False
# 4               False    False           False
#
# [5 rows x 169 columns]

# %%
hero_df = pd.merge(Left,Right, left_on='Hero', right_on='hero_names')

# %%
hero_df
# Out:
#      Gender               Race Alignment        Hair color Eye color  \
# 0      Male              Human      good           No Hair    yellow
# 1      Male      Icthyo Sapien      good           No Hair      blue
# 2      Male            Ungaran      good           No Hair      blue
# 3      Male  Human / Radiation       bad           No Hair     green
# 4      Male              Human       bad           No Hair      blue
# ..      ...                ...       ...               ...       ...
# 458    Male              Human      good             Blond      blue
# 459  Female              Human      good  Strawberry Blond      blue
# 460    Male     Yoda's species      good             White     brown
# 461  Female              Human      good             Black      blue
# 462    Male            Unknown       bad             Brown       red
#
#     Skin color  height (cm) weight (kg)             Hero          Publisher  \
# 0      Unknown        203.0       441.0           A-Bomb      Marvel Comics
# 1         blue        191.0        65.0       Abe Sapien  Dark Horse Comics
# 2          red        185.0        90.0         Abin Sur          DC Comics
# 3      Unknown        203.0       441.0      Abomination      Marvel Comics
# 4      Unknown        193.0       122.0    Absorbing Man      Marvel Comics
# ..         ...          ...         ...              ...                ...
# 458    Unknown        183.0        83.0     Yellowjacket      Marvel Comics
# 459    Unknown        165.0        52.0  Yellowjacket II      Marvel Comics
# 460      green         66.0        17.0             Yoda       George Lucas
# 461    Unknown        170.0        57.0          Zatanna          DC Comics
# 462    Unknown        185.0        81.0             Zoom          DC Comics
#
#      ...  Weather Control Omnipresent Omniscient  Hair Manipulation  \
# 0    ...            False       False      False              False
# 1    ...            False       False      False              False
# 2    ...            False       False      False              False
# 3    ...            False       False      False              False
# 4    ...            False       False      False              False
# ..   ...              ...         ...        ...                ...
# 458  ...            False       False      False              False
# 459  ...            False       False      False              False
# 460  ...            False       False      False              False
# 461  ...             True       False      False              False
# 462  ...            False       False      False              False
#
#      Nova Force  Odin Force  Phoenix Force  Intuitive aptitude  Melting  \
# 0         False       False          False               False    False
# 1         False       False          False               False    False
# 2         False       False          False               False    False
# 3         False       False          False               False    False
# 4         False       False          False               False    False
# ..          ...         ...            ...                 ...      ...
# 458       False       False          False               False    False
# 459       False       False          False               False    False
# 460       False       False          False               False    False
# 461       False       False          False               False    False
# 462       False       False          False               False    False
#
#      Changing Armor
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ..              ...
# 458           False
# 459           False
# 460           False
# 461           False
# 462           False
#
# [463 rows x 180 columns]

# %% [markdown]
# 1. Compare the average weight of super powers who have Super Speed to those who do not.

# %%
speed_filter = hero_df['Super Speed']==True

# %%
hero_df[speed_filter].head()
# Out:
#    Gender               Race Alignment Hair color Eye color Skin color  \
# 3    Male  Human / Radiation       bad    No Hair     green    Unknown
# 5    Male              Human      good      Blond      blue    Unknown
# 8    Male            Unknown       bad      White      blue    Unknown
# 9    Male             Cyborg       bad      Black     brown    Unknown
# 10   Male            Unknown      good      Blond      blue    Unknown
#
#     height (cm) weight (kg)          Hero      Publisher  ...  \
# 3         203.0       441.0   Abomination  Marvel Comics  ...
# 5         185.0        88.0  Adam Strange      DC Comics  ...
# 8         188.0       108.0    Air-Walker  Marvel Comics  ...
# 9         193.0        90.0          Ajax  Marvel Comics  ...
# 10        180.0        90.0    Alan Scott      DC Comics  ...
#
#     Weather Control Omnipresent Omniscient  Hair Manipulation  Nova Force  \
# 3             False       False      False              False       False
# 5             False       False      False              False       False
# 8             False       False      False              False       False
# 9             False       False      False              False       False
# 10            False       False      False              False       False
#
#     Odin Force  Phoenix Force  Intuitive aptitude  Melting  Changing Armor
# 3        False          False               False    False           False
# 5        False          False               False    False           False
# 8        False          False               False    False           False
# 9        False          False               False    False           False
# 10       False          False               False    False           False
#
# [5 rows x 180 columns]

# %%
hero_df[speed_filter].describe()
# Out:
#        height (cm)  weight (kg)
# count   198.000000    198.000000
# mean    189.444444    129.404040
# std      56.186730    122.625087
# min      64.000000     14.000000
# 25%     178.000000     69.250000
# 50%     183.000000     90.000000
# 75%     193.000000    135.000000
# max     876.000000    855.000000

# %%
hero_df[~speed_filter].describe()
# Out:
#        height (cm)  weight (kg)
# count   265.000000    265.000000
# mean    186.376226    101.773585
# std      63.402018     91.745168
# min      15.200000      4.000000
# 25%     170.000000     59.000000
# 50%     183.000000     79.000000
# 75%     188.000000     97.000000
# max     975.000000    900.000000

# %% [markdown]
# 2. What is the average height of heroes for each publisher?

# %%
pub_list = hero_df.groupby(by='Publisher')

# %%
pub_list.head()
# Out:
#      Gender               Race Alignment  Hair color Eye color Skin color  \
# 0      Male              Human      good     No Hair    yellow    Unknown
# 1      Male      Icthyo Sapien      good     No Hair      blue       blue
# 2      Male            Ungaran      good     No Hair      blue        red
# 3      Male  Human / Radiation       bad     No Hair     green    Unknown
# 4      Male              Human       bad     No Hair      blue    Unknown
# 5      Male              Human      good       Blond      blue    Unknown
# 6      Male              Human      good       Brown     brown    Unknown
# 7      Male            Unknown      good     Unknown   Unknown    Unknown
# 10     Male            Unknown      good       Blond      blue    Unknown
# 11     Male    Xenomorph XX121       bad     No Hair   Unknown      black
# 12     Male            Android       bad     Unknown       red    Unknown
# 17     Male              Human      good       Blond      blue    Unknown
# 84   Female              Human      good       Blond     green    Unknown
# 105    Male            Unknown       bad  Red / Grey     brown    Unknown
# 120    Male             Cyborg       bad     No Hair    yellow    Unknown
# 121    Male              Human      good       Blond      blue    Unknown
# 142  Female              Human      good       Brown     brown    Unknown
# 176    Male             Saiyan      good     Unknown   Unknown    Unknown
# 189    Male              Human      good       Brown     brown    Unknown
# 214    Male              Human      good     Unknown   Unknown    Unknown
# 221    Male              Human      good       Brown     hazel    Unknown
# 254    Male              Human      good       Blond      blue    Unknown
# 264    Male            Unknown      good       Black      blue    Unknown
# 297    Male              Human      good     Unknown   Unknown    Unknown
# 306    Male            Unknown      good       Black     brown    Unknown
# 307    Male              Human      good     No Hair   Unknown    Unknown
# 331    Male              Human      good       Black     brown    Unknown
# 381    Male              Demon      good       Black     brown    Unknown
# 390    Male       Human-Vulcan      good       Black     brown    Unknown
# 430  Female            Unknown      good       Black     hazel    Unknown
# 433    Male             Saiyan       bad       Black   Unknown    Unknown
# 460    Male     Yoda's species      good       White     brown      green
#
#      height (cm) weight (kg)            Hero          Publisher  ...  \
# 0          203.0       441.0          A-Bomb      Marvel Comics  ...
# 1          191.0        65.0      Abe Sapien  Dark Horse Comics  ...
# 2          185.0        90.0        Abin Sur          DC Comics  ...
# 3          203.0       441.0     Abomination      Marvel Comics  ...
# 4          193.0       122.0   Absorbing Man      Marvel Comics  ...
# 5          185.0        88.0    Adam Strange          DC Comics  ...
# 6          178.0        81.0       Agent Bob      Marvel Comics  ...
# 7          191.0       104.0      Agent Zero      Marvel Comics  ...
# 10         180.0        90.0      Alan Scott          DC Comics  ...
# 11         244.0       169.0           Alien  Dark Horse Comics  ...
# 12         257.0       173.0           Amazo          DC Comics  ...
# 17         183.0        83.0      Animal Man          DC Comics  ...
# 84         157.0        52.0           Buffy  Dark Horse Comics  ...
# 105        185.0        86.0         Chromos       Team Epic TV  ...
# 120        198.0       135.0     Darth Vader       George Lucas  ...
# 121        122.0        27.0            Dash  Dark Horse Comics  ...
# 142        168.0        56.0      Elastigirl  Dark Horse Comics  ...
# 176        175.0        62.0            Goku           Shueisha  ...
# 189        183.0        79.0        Han Solo       George Lucas  ...
# 214        183.0        79.0   Indiana Jones       George Lucas  ...
# 221        178.0        77.0   James T. Kirk          Star Trek  ...
# 254        168.0        77.0  Luke Skywalker       George Lucas  ...
# 264        183.0        81.0    Master Brood       Team Epic TV  ...
# 297        168.0        54.0  Naruto Uzumaki           Shueisha  ...
# 306        180.0        65.0      Omniscient       Team Epic TV  ...
# 307        175.0        69.0   One Punch Man           Shueisha  ...
# 331        178.0        83.0           Rambo            Unknown  ...
# 381        211.0       405.0           Spawn       Image Comics  ...
# 390        185.0        81.0           Spock          Star Trek  ...
# 430        175.0        56.0    Valerie Hart       Team Epic TV  ...
# 433        168.0        73.0          Vegeta           Shueisha  ...
# 460         66.0        17.0            Yoda       George Lucas  ...
#
#      Weather Control Omnipresent Omniscient  Hair Manipulation  Nova Force  \
# 0              False       False      False              False       False
# 1              False       False      False              False       False
# 2              False       False      False              False       False
# 3              False       False      False              False       False
# 4              False       False      False              False       False
# 5              False       False      False              False       False
# 6              False       False      False              False       False
# 7              False       False      False              False       False
# 10             False       False      False              False       False
# 11             False       False      False              False       False
# 12             False       False      False              False       False
# 17             False       False      False              False       False
# 84             False       False      False              False       False
# 105            False       False      False              False       False
# 120            False       False      False              False       False
# 121            False       False      False              False       False
# 142            False       False      False              False       False
# 176            False       False      False              False       False
# 189            False       False      False              False       False
# 214            False       False      False              False       False
# 221            False       False      False              False       False
# 254            False       False      False              False       False
# 264            False       False      False              False       False
# 297             True       False      False              False       False
# 306            False       False      False              False       False
# 307            False       False      False              False       False
# 331            False       False      False              False       False
# 381            False       False      False              False       False
# 390            False       False      False              False       False
# 430            False       False      False              False       False
# 433            False       False      False              False       False
# 460            False       False      False              False       False
#
#      Odin Force  Phoenix Force  Intuitive aptitude  Melting  Changing Armor
# 0         False          False               False    False           False
# 1         False          False               False    False           False
# 2         False          False               False    False           False
# 3         False          False               False    False           False
# 4         False          False               False    False           False
# 5         False          False               False    False           False
# 6         False          False               False    False           False
# 7         False          False               False    False           False
# 10        False          False               False    False           False
# 11        False          False               False    False           False
# 12        False          False               False    False           False
# 17        False          False               False    False           False
# 84        False          False               False    False           False
# 105       False          False               False    False           False
# 120       False          False               False    False           False
# 121       False          False               False    False           False
# 142       False          False               False    False           False
# 176       False          False               False    False           False
# 189       False          False               False    False           False
# 214       False          False               False    False           False
# 221       False          False               False    False           False
# 254       False          False               False    False           False
# 264       False          False               False    False           False
# 297       False          False               False    False           False
# 306       False          False               False    False           False
# 307       False          False               False    False           False
# 331       False          False               False    False           False
# 381       False          False               False    False           False
# 390       False          False               False    False           False
# 430       False          False               False    False            True
# 433       False          False               False    False           False
# 460       False          False               False    False           False
#
# [32 rows x 180 columns]

# %%
pub_list['height (cm)'].mean()
# Out:
# Publisher
# DC Comics            181.923913
# Dark Horse Comics    176.909091
# George Lucas         159.600000
# Image Comics         211.000000
# Marvel Comics        191.546128
# Shueisha             171.500000
# Star Trek            181.500000
# Team Epic TV         180.750000
# Unknown              178.000000
# Name: height (cm), dtype: float64

# %%
pub_list['height (cm)'].describe()
# Out:
#                    count        mean        std    min     25%    50%     75%  \
# Publisher
# DC Comics          138.0  181.923913  23.991856   62.5  173.00  183.0  188.00
# Dark Horse Comics   11.0  176.909091  54.459994   71.0  147.00  183.0  207.00
# George Lucas         5.0  159.600000  53.388201   66.0  168.00  183.0  183.00
# Image Comics         1.0  211.000000        NaN  211.0  211.00  211.0  211.00
# Marvel Comics      297.0  191.546128  72.316521   15.2  175.00  183.0  191.00
# Shueisha             4.0  171.500000   4.041452  168.0  168.00  171.5  175.00
# Star Trek            2.0  181.500000   4.949747  178.0  179.75  181.5  183.25
# Team Epic TV         4.0  180.750000   4.349329  175.0  178.75  181.5  183.50
# Unknown              1.0  178.000000        NaN  178.0  178.00  178.0  178.00
#
#                      max
# Publisher
# DC Comics          279.0
# Dark Horse Comics  259.0
# George Lucas       198.0
# Image Comics       211.0
# Marvel Comics      975.0
# Shueisha           175.0
# Star Trek          185.0
# Team Epic TV       185.0
# Unknown            178.0
